# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from matplotlib.pyplot import imread
from skimage.transform import resize as imresize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('../Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('../Project_data/val.csv').readlines())
batch_size = 32

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
x = 30 # number of frames
y = 160 # image width
z = 160 # image height
channels=3
classes=5

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx =[x for x in range(0,x)]   #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size    # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    temp = imresize(image,(y,z))
                    temp = temp/255 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])  #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    temp = imresize(image,(y,z))
                    temp = temp/255 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '../Project_data/train'
val_path = '../Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs =   10  # choose the number of epochs
print ('# epochs =', num_epochs)
num_batches = num_train_sequences//batch_size 
print(num_batches)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10
# 20

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# #### Experiment 1: Creating a model with 160x160 image size,epochs=10 and batch_size=32

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout

#write your model here
model_1 = Sequential()

model_1.add(Conv3D(8, #number of filters 
                 kernel_size=(3,3,3), 
                 input_shape=(x,y,z,channels),
                 padding='same'))

model_1.add(Activation('relu'))
model_1.add(BatchNormalization())

model_1.add(MaxPooling3D(pool_size=(2,2,2)))

model_1.add(Conv3D(16, #Number of filters, 
                 kernel_size=(3,3,3), 
                 padding='same'))

model_1.add(Activation('relu'))
model_1.add(BatchNormalization())
model_1.add(MaxPooling3D(pool_size=(2,2,2)))

model_1.add(Conv3D(32, #Number of filters 
                 kernel_size=(1,3,3), 
                 padding='same'))

model_1.add(Activation('relu'))
model_1.add(BatchNormalization())
model_1.add(MaxPooling3D(pool_size=(2,2,2)))


model_1.add(Conv3D(64, #Number pf filters 
                 kernel_size=(1,3,3), 
                 padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))



#Flatten Layers
model_1.add(Flatten())

model_1.add(Dense(100, activation='relu'))
model_1.add(Dropout(0.5))


#softmax layer
model_1.add(Dense(classes, activation='softmax'))
# Out:
# 2022-05-16 16:55:22.361295: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-05-16 16:55:22.361376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14803 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:3d:00.0, compute capability: 7.5

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = 'adam'
model_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_1.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 160, 160, 8)   656
#
#  activation (Activation)     (None, 30, 160, 160, 8)   0
#
#  batch_normalization (BatchN  (None, 30, 160, 160, 8)  32
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 80, 80, 8)    0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 80, 80, 16)    3472
#
#  activation_1 (Activation)   (None, 15, 80, 80, 16)    0
#
#  batch_normalization_1 (Batc  (None, 15, 80, 80, 16)   64
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 40, 40, 16)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 40, 40, 32)     4640
#
#  activation_2 (Activation)   (None, 7, 40, 40, 32)     0
#
#  batch_normalization_2 (Batc  (None, 7, 40, 40, 32)    128
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 20, 20, 32)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 3, 20, 20, 64)     18496
#
#  batch_normalization_3 (Batc  (None, 3, 20, 20, 64)    256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 3, 20, 20, 64)     0
#
#  flatten (Flatten)           (None, 76800)             0
#
#  dense (Dense)               (None, 100)               7680100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 5)                 505
#
# =================================================================
# Total params: 7,708,349
# Trainable params: 7,708,109
# Non-trainable params: 240
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, cooldown=1, verbose=1)# write the REducelronplateau code here
earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
callbacks_list = [checkpoint, LR, earlystop]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model_1.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ../Project_data/train ; batch size = 32
# Epoch 1/10
# 2022-05-16 12:28:26.097237: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 19/21 [==========================>...] - ETA: 14s - loss: 7.9989 - categorical_accuracy: 0.3125Batch:  21 Index: 32
# 21/21 [==============================] - ETA: 0s - loss: 7.4602 - categorical_accuracy: 0.3167Source path =  ../Project_data/val ; batch size = 32
# Batch:  4 Index: 32
#
# Epoch 00001: saving model to model_init_2022-05-1612_28_10.178322/model-00001-7.46022-0.31674-1.64010-0.21000.h5
# 21/21 [==============================] - 182s 9s/step - loss: 7.4602 - categorical_accuracy: 0.3167 - val_loss: 1.6401 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/10
# 21/21 [==============================] - ETA: 0s - loss: 1.4069 - categorical_accuracy: 0.3706
# Epoch 00002: saving model to model_init_2022-05-1612_28_10.178322/model-00002-1.40691-0.37060-1.66017-0.25000.h5
# 21/21 [==============================] - 115s 6s/step - loss: 1.4069 - categorical_accuracy: 0.3706 - val_loss: 1.6602 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/10
#  6/21 [=======>......................] - ETA: 1:23 - loss: 1.3965 - categorical_accuracy: 0.3841Batch:  29 Index: 23
# 21/21 [==============================] - ETA: 0s - loss: 1.3112 - categorical_accuracy: 0.4473
# Epoch 00003: saving model to model_init_2022-05-1612_28_10.178322/model-00003-1.31121-0.44731-1.63718-0.18750.h5
# 21/21 [==============================] - 104s 5s/step - loss: 1.3112 - categorical_accuracy: 0.4473 - val_loss: 1.6372 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 4/10
# 20/21 [===========================>..] - ETA: 4s - loss: 1.2315 - categorical_accuracy: 0.4553Batch:  35 Index: 19
# 21/21 [==============================] - ETA: 0s - loss: 1.2357 - categorical_accuracy: 0.4511
# Epoch 00004: saving model to model_init_2022-05-1612_28_10.178322/model-00004-1.23574-0.45113-1.86216-0.18750.h5
# 21/21 [==============================] - 93s 5s/step - loss: 1.2357 - categorical_accuracy: 0.4511 - val_loss: 1.8622 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 5/10
# 21/21 [==============================] - ETA: 0s - loss: 1.2540 - categorical_accuracy: 0.4622
# Epoch 00005: saving model to model_init_2022-05-1612_28_10.178322/model-00005-1.25399-0.46218-2.31401-0.12500.h5
# 21/21 [==============================] - 91s 4s/step - loss: 1.2540 - categorical_accuracy: 0.4622 - val_loss: 2.3140 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 6/10
# 21/21 [==============================] - ETA: 0s - loss: 1.1953 - categorical_accuracy: 0.4174
# Epoch 00006: saving model to model_init_2022-05-1612_28_10.178322/model-00006-1.19533-0.41737-2.65137-0.18750.h5
# 21/21 [==============================] - 83s 4s/step - loss: 1.1953 - categorical_accuracy: 0.4174 - val_loss: 2.6514 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 7/10
# 21/21 [==============================] - ETA: 0s - loss: 1.2749 - categorical_accuracy: 0.4230
# Epoch 00007: saving model to model_init_2022-05-1612_28_10.178322/model-00007-1.27491-0.42297-2.26479-0.31250.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 86s 4s/step - loss: 1.2749 - categorical_accuracy: 0.4230 - val_loss: 2.2648 - val_categorical_accuracy: 0.3125 - lr: 0.0010
# Epoch 8/10
# 21/21 [==============================] - ETA: 0s - loss: 1.1772 - categorical_accuracy: 0.4202
# Epoch 00008: saving model to model_init_2022-05-1612_28_10.178322/model-00008-1.17723-0.42017-2.43286-0.12500.h5
# 21/21 [==============================] - 88s 4s/step - loss: 1.1772 - categorical_accuracy: 0.4202 - val_loss: 2.4329 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 9/10
# 21/21 [==============================] - ETA: 0s - loss: 1.1656 - categorical_accuracy: 0.4398
# Epoch 00009: saving model to model_init_2022-05-1612_28_10.178322/model-00009-1.16560-0.43978-3.29575-0.18750.h5
# 21/21 [==============================] - 85s 4s/step - loss: 1.1656 - categorical_accuracy: 0.4398 - val_loss: 3.2957 - val_categorical_accuracy: 0.1875 - lr: 2.0000e-04
# Epoch 10/10
# 21/21 [==============================] - ETA: 0s - loss: 1.1383 - categorical_accuracy: 0.4258
# Epoch 00010: saving model to model_init_2022-05-1612_28_10.178322/model-00010-1.13826-0.42577-4.63461-0.00000.h5
# 21/21 [==============================] - 87s 4s/step - loss: 1.1383 - categorical_accuracy: 0.4258 - val_loss: 4.6346 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04

# %% [markdown]
# Not good results

# %% [markdown]
# #### Exp -2 :   Reduce the batch size to 20 and image dimensions to 60x60 with 30 frames

# %%
channels=3
classes=5


x = 30 # number of frames
y = 60 # image width
z = 60 # image height
batch_size=20

def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx =[x for x in range(0,x)]   #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size    # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    temp = imresize(image,(y,z))
                    temp = temp/255 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])  #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    temp = imresize(image,(y,z))
                    temp = temp/255 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %%
curr_dt_time = datetime.datetime.now()
train_path = '../Project_data/train'
val_path = '../Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs =   10  # choose the number of epochs
print ('# epochs =', num_epochs)
num_batches = num_train_sequences//batch_size 
print(num_batches)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10
# 33

# %%
#define model
model_b = Sequential()
model_b.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=(x,y,z,channels), padding='same'))
model_b.add(Activation('relu'))
model_b.add(BatchNormalization())
model_b.add(MaxPooling3D(pool_size=(2, 2, 2)))

model_b.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model_b.add(Activation('relu'))
model_b.add(BatchNormalization())
model_b.add(MaxPooling3D(pool_size=(2, 2, 2)))


model_b.add(Conv3D(64, kernel_size=(3,3,3), padding='same'))
model_b.add(Activation('relu'))
model_b.add(BatchNormalization())
model_b.add(MaxPooling3D(pool_size=(2, 2, 2)))

model_b.add(Flatten())
model_b.add(Dense(128, activation='relu'))
model_b.add(Dropout(0.25))
model_b.add(Dense(64, activation='relu'))
model_b.add(Dropout(0.25))
model_b.add(Dense(classes, activation='softmax'))

# %%
optimiser = 'adam'
model_b.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_b.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 30, 60, 60, 16)    1312
#
#  activation_4 (Activation)   (None, 30, 60, 60, 16)    0
#
#  batch_normalization_4 (Batc  (None, 30, 60, 60, 16)   64
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 15, 30, 30, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 30, 30, 32)    13856
#
#  activation_5 (Activation)   (None, 15, 30, 30, 32)    0
#
#  batch_normalization_5 (Batc  (None, 15, 30, 30, 32)   128
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 7, 15, 15, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 7, 15, 15, 64)     55360
#
#  activation_6 (Activation)   (None, 7, 15, 15, 64)     0
#
#  batch_normalization_6 (Batc  (None, 7, 15, 15, 64)    256
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 3, 7, 7, 64)      0
#  3D)
#
#  flatten_1 (Flatten)         (None, 9408)              0
#
#  dense_2 (Dense)             (None, 128)               1204352
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,283,909
# Trainable params: 1,283,685
# Non-trainable params: 224
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, cooldown=1, verbose=1)# write the REducelronplateau code here
earlystop = EarlyStopping(monitor="val_loss", min_delta=0,patience=10,verbose=1)
callbacks_list = [checkpoint, LR,earlystop]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
model_b.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ../Project_data/train ; batch size = 20
# Epoch 1/10
# 32/34 [===========================>..] - ETA: 8s - loss: 2.6391 - categorical_accuracy: 0.3750 Batch:  34 Index: 20
# 34/34 [==============================] - ETA: 0s - loss: 2.6056 - categorical_accuracy: 0.3695Source path =  ../Project_data/val ; batch size = 20
#
# Epoch 00001: saving model to model_init_2022-05-1613_07_08.720968/model-00001-2.60563-0.36953-6.70491-0.22000.h5
# 34/34 [==============================] - 173s 5s/step - loss: 2.6056 - categorical_accuracy: 0.3695 - val_loss: 6.7049 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 2/10
# 34/34 [==============================] - ETA: 0s - loss: 2.4060 - categorical_accuracy: 0.3137
# Epoch 00002: saving model to model_init_2022-05-1613_07_08.720968/model-00002-2.40596-0.31373-14.48957-0.22000.h5
# 34/34 [==============================] - 51s 2s/step - loss: 2.4060 - categorical_accuracy: 0.3137 - val_loss: 14.4896 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 3/10
# 34/34 [==============================] - ETA: 0s - loss: 3.3064 - categorical_accuracy: 0.3725
# Epoch 00003: saving model to model_init_2022-05-1613_07_08.720968/model-00003-3.30644-0.37255-19.10740-0.19000.h5
# 34/34 [==============================] - 56s 2s/step - loss: 3.3064 - categorical_accuracy: 0.3725 - val_loss: 19.1074 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 4/10
# 34/34 [==============================] - ETA: 0s - loss: 3.0457 - categorical_accuracy: 0.2059
# Epoch 00004: saving model to model_init_2022-05-1613_07_08.720968/model-00004-3.04570-0.20588-20.63623-0.25000.h5
# 34/34 [==============================] - 52s 2s/step - loss: 3.0457 - categorical_accuracy: 0.2059 - val_loss: 20.6362 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 5/10
# 34/34 [==============================] - ETA: 0s - loss: 2.7250 - categorical_accuracy: 0.2157
# Epoch 00005: saving model to model_init_2022-05-1613_07_08.720968/model-00005-2.72501-0.21569-21.57136-0.23000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 54s 2s/step - loss: 2.7250 - categorical_accuracy: 0.2157 - val_loss: 21.5714 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 6/10
# 34/34 [==============================] - ETA: 0s - loss: 1.8299 - categorical_accuracy: 0.2353
# Epoch 00006: saving model to model_init_2022-05-1613_07_08.720968/model-00006-1.82993-0.23529-23.64424-0.22000.h5
# 34/34 [==============================] - 54s 2s/step - loss: 1.8299 - categorical_accuracy: 0.2353 - val_loss: 23.6442 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 7/10
# 34/34 [==============================] - ETA: 0s - loss: 1.7281 - categorical_accuracy: 0.2353
# Epoch 00007: saving model to model_init_2022-05-1613_07_08.720968/model-00007-1.72808-0.23529-25.67432-0.24000.h5
# 34/34 [==============================] - 54s 2s/step - loss: 1.7281 - categorical_accuracy: 0.2353 - val_loss: 25.6743 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 8/10
# 34/34 [==============================] - ETA: 0s - loss: 1.7200 - categorical_accuracy: 0.2353
# Epoch 00008: saving model to model_init_2022-05-1613_07_08.720968/model-00008-1.72004-0.23529-25.71859-0.23000.h5
# 34/34 [==============================] - 55s 2s/step - loss: 1.7200 - categorical_accuracy: 0.2353 - val_loss: 25.7186 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 9/10
# 34/34 [==============================] - ETA: 0s - loss: 1.5711 - categorical_accuracy: 0.2745
# Epoch 00009: saving model to model_init_2022-05-1613_07_08.720968/model-00009-1.57112-0.27451-27.16920-0.22000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 52s 2s/step - loss: 1.5711 - categorical_accuracy: 0.2745 - val_loss: 27.1692 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 10/10
# 34/34 [==============================] - ETA: 0s - loss: 1.5843 - categorical_accuracy: 0.2549
# Epoch 00010: saving model to model_init_2022-05-1613_07_08.720968/model-00010-1.58426-0.25490-27.88949-0.19000.h5
# 34/34 [==============================] - 54s 2s/step - loss: 1.5843 - categorical_accuracy: 0.2549 - val_loss: 27.8895 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05

# %% [markdown]
# #### Exp-3 :adding more layers and increase the no of epochs to 15

# %%
x = 30 # number of frames
y = 60 # image width
z = 60 # image height

batch_size=20
num_epochs=15

# %%
model_b1 = Sequential()
model_b1.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=(x,y,z,channels), padding='same'))
model_b1.add(Activation('relu'))
model_b1.add(BatchNormalization())

model_b1.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=(x,y,z,channels), padding='same'))
model_b1.add(Activation('relu'))
model_b1.add(BatchNormalization())

model_b1.add(MaxPooling3D(pool_size=(2, 2, 2)))

model_b1.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model_b1.add(Activation('relu'))
model_b1.add(BatchNormalization())

model_b1.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model_b1.add(Activation('relu'))
model_b1.add(BatchNormalization())

model_b1.add(MaxPooling3D(pool_size=(2, 2, 2)))


model_b1.add(Conv3D(64, kernel_size=(3,3,3), padding='same'))
model_b1.add(Activation('relu'))
model_b1.add(BatchNormalization())

model_b1.add(Conv3D(64, kernel_size=(3,3,3), padding='same'))
model_b1.add(Activation('relu'))
model_b1.add(BatchNormalization())

model_b1.add(MaxPooling3D(pool_size=(2, 2, 2)))

model_b1.add(Flatten())
model_b1.add(Dense(128, activation='relu'))
model_b1.add(Dropout(0.25))
model_b1.add(Dense(64, activation='relu'))
model_b1.add(Dropout(0.25))
model_b1.add(Dense(classes, activation='softmax'))

# %%
optimiser = 'adam'
model_b1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_b1.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_7 (Conv3D)           (None, 30, 60, 60, 16)    1312
#
#  activation_7 (Activation)   (None, 30, 60, 60, 16)    0
#
#  batch_normalization_7 (Batc  (None, 30, 60, 60, 16)   64
#  hNormalization)
#
#  conv3d_8 (Conv3D)           (None, 30, 60, 60, 16)    6928
#
#  activation_8 (Activation)   (None, 30, 60, 60, 16)    0
#
#  batch_normalization_8 (Batc  (None, 30, 60, 60, 16)   64
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 15, 30, 30, 16)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 15, 30, 30, 32)    13856
#
#  activation_9 (Activation)   (None, 15, 30, 30, 32)    0
#
#  batch_normalization_9 (Batc  (None, 15, 30, 30, 32)   128
#  hNormalization)
#
#  conv3d_10 (Conv3D)          (None, 15, 30, 30, 32)    27680
#
#  activation_10 (Activation)  (None, 15, 30, 30, 32)    0
#
#  batch_normalization_10 (Bat  (None, 15, 30, 30, 32)   128
#  chNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 7, 15, 15, 32)    0
#  3D)
#
#  conv3d_11 (Conv3D)          (None, 7, 15, 15, 64)     55360
#
#  activation_11 (Activation)  (None, 7, 15, 15, 64)     0
#
#  batch_normalization_11 (Bat  (None, 7, 15, 15, 64)    256
#  chNormalization)
#
#  conv3d_12 (Conv3D)          (None, 7, 15, 15, 64)     110656
#
#  activation_12 (Activation)  (None, 7, 15, 15, 64)     0
#
#  batch_normalization_12 (Bat  (None, 7, 15, 15, 64)    256
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 3, 7, 7, 64)      0
#  3D)
#
#  flatten_2 (Flatten)         (None, 9408)              0
#
#  dense_5 (Dense)             (None, 128)               1204352
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,429,621
# Trainable params: 1,429,173
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
model_b1.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ../Project_data/train ; batch size = 20
# Epoch 1/15
# 32/34 [===========================>..] - ETA: 8s - loss: 3.0349 - categorical_accuracy: 0.3156 Batch:  34 Index: 20
# 34/34 [==============================] - ETA: 0s - loss: 3.0176 - categorical_accuracy: 0.3167Source path =  ../Project_data/val ; batch size = 20
#
# Epoch 00001: saving model to model_init_2022-05-1613_07_08.720968/model-00001-3.01757-0.31674-1.82019-0.21000.h5
# 34/34 [==============================] - 171s 5s/step - loss: 3.0176 - categorical_accuracy: 0.3167 - val_loss: 1.8202 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2
- val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 00011: early stopping

# %% [markdown]
# From exp-2 and exp-3 there is very small change in training and validation accuracy even though we increase the no of layers and no of epochs.We can see the model is more impacted by image resolution,batch size and no of frames.

# %% [markdown]
# #### Exp 4:change the image resolution to 80x80  ,with frames=30 and  by keeping batchsize=10 and epochs=20

# %%
x = 30 # number of frames
y = 80 # image width
z = 80 # image height

batch_size=10
num_epochs=20

# %%
model_b2 = Sequential()
model_b2.add(Conv3D(8, kernel_size=(3, 3, 3), input_shape=(x,y,z,channels), padding='same'))
model_b2.add(Activation('relu'))
model_b2.add(BatchNormalization())



model_b2.add(MaxPooling3D(pool_size=(2, 2, 2)))


model_b2.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model_b2.add(Activation('relu'))
model_b2.add(BatchNormalization())

model_b2.add(MaxPooling3D(pool_size=(2, 2, 2)))


model_b2.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model_b2.add(Activation('relu'))
model_b2.add(BatchNormalization())

model_b2.add(MaxPooling3D(pool_size=(2, 2, 2)))

model_b2.add(Conv3D(64, kernel_size=(3,3,3), padding='same'))
model_b2.add(Activation('relu'))
model_b2.add(BatchNormalization())

model_b2.add(MaxPooling3D(pool_size=(2, 2, 2)))


model_b2.add(Flatten())
model_b2.add(Dense(1000, activation='relu'))
model_b2.add(Dropout(0.5))
model_b2.add(Dense(500, activation='relu'))
model_b2.add(Dropout(0.5))
model_b2.add(Dense(classes, activation='softmax'))

# %%
optimiser = 'adam'
model_b2.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_b2.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_13 (Conv3D)          (None, 30, 80, 80, 8)     656
#
#  activation_13 (Activation)  (None, 30, 80, 80, 8)     0
#
#  batch_normalization_13 (Bat  (None, 30, 80, 80, 8)    32
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 15, 40, 40, 8)    0
#  3D)
#
#  conv3d_14 (Conv3D)          (None, 15, 40, 40, 16)    3472
#
#  activation_14 (Activation)  (None, 15, 40, 40, 16)    0
#
#  batch_normalization_14 (Bat  (None, 15, 40, 40, 16)   64
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 7, 20, 20, 16)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 7, 20, 20, 32)     13856
#
#  activation_15 (Activation)  (None, 7, 20, 20, 32)     0
#
#  batch_normalization_15 (Bat  (None, 7, 20, 20, 32)    128
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 3, 10, 10, 32)    0
#  g3D)
#
#  conv3d_16 (Conv3D)          (None, 3, 10, 10, 64)     55360
#
#  activation_16 (Activation)  (None, 3, 10, 10, 64)     0
#
#  batch_normalization_16 (Bat  (None, 3, 10, 10, 64)    256
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 1, 5, 5, 64)      0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 1600)              0
#
#  dense_8 (Dense)             (None, 1000)              1601000
#
#  dropout_5 (Dropout)         (None, 1000)              0
#
#  dense_9 (Dense)             (None, 500)               500500
#
#  dropout_6 (Dropout)         (None, 500)               0
#
#  dense_10 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 2,177,829
# Trainable params: 2,177,589
# Non-trainable params: 240
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.1866 - categorical_accuracy: 0.9502 - val_loss: 0.5434 - val_categorical_accuracy: 0.8000 - lr: 2.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2123 - categorical_accuracy: 0.9204
# Epoch 00020: saving model to model_init_2022-05-1613_07_08.720968/model-00020-0.21228-0.92040-0.49639-0.85000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 0.2123 - categorical_accuracy: 0.9204 - val_loss: 0.4964 - val_categorical_accuracy: 0.8500 - lr: 2.0000e-04

# %% [markdown]
# Here training accuracy of 92% and validation accuracy of 85%. So this model is a good model and can be used for further analysis.

# %% [markdown]
# ####  For CONV 3D model the model in exp 4 isthe best one.

# %% [markdown]
# ## Conv2D + RNN to build a model

# %%
x = 30 # number of frames
y = 100 # image width
z = 100 # image height
batch_size=10
num_epochs=30
channels=3
classes=5

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx =[x for x in range(0,x)]   #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size    # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    temp = imresize(image,(y,z))
                    temp = temp/255 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])  #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x,y,z,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    temp = imresize(image,(y,z))
                    temp = temp/255 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %%
curr_dt_time = datetime.datetime.now()
train_path = '../Project_data/train'
val_path = '../Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs =   30  # choose the number of epochs
print ('# epochs =', num_epochs)
num_batches = num_train_sequences//batch_size 
print(num_batches)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30
# 66

# %% [markdown]
# #### Exp- 5 :custom conv2d + GRU

# %%
#define model

from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout


input_shape=(x,y,z,channels)
model_d= Sequential()

model_d.add(TimeDistributed(Conv2D(16, kernel_size=(3, 3),  padding='same'),input_shape=input_shape))
model_d.add(TimeDistributed(Activation('relu')))
model_d.add(TimeDistributed(BatchNormalization()))


model_d.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d.add(TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding='same')))
model_d.add(TimeDistributed(Activation('relu')))
model_d.add(TimeDistributed(BatchNormalization()))


model_d.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d.add(TimeDistributed(Conv2D(64, kernel_size=(3, 3),  padding='same')))
model_d.add(TimeDistributed(Activation('relu')))
model_d.add(TimeDistributed(BatchNormalization()))


model_d.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d.add(TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding='same')))
model_d.add(TimeDistributed(Activation('relu')))
model_d.add(TimeDistributed(BatchNormalization()))


model_d.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d.add(TimeDistributed(Flatten()))

model_d.add(GRU(64))
model_d.add(Dropout(0.25))

model_d.add(Dense(64,activation='relu'))
model_d.add(Dropout(0.25))

model_d.add(Dense(classes, activation='softmax'))

# %%
optimiser=tf.keras.optimizers.Adam()
model_d.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_d.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 30, 100, 100, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 100, 100, 16)  0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 100, 100, 16)  64
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 50, 50, 16)   0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 30, 50, 50, 32)   4640
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 50, 50, 32)   0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 50, 50, 32)   128
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 30, 25, 25, 32)   0
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 30, 25, 25, 64)   18496
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 30, 25, 25, 64)   0
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 30, 25, 25, 64)   256
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 30, 12, 12, 64)   0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 30, 12, 12, 128)  73856
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 30, 12, 12, 128)  0
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 30, 12, 12, 128)  512
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 30, 6, 6, 128)    0
#  stributed)
#
#  time_distributed_16 (TimeDi  (None, 30, 4608)         0
#  stributed)
#
#  gru (GRU)                   (None, 64)                897408
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 64)                4160
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1,000,293
# Trainable params: 999,813
# Non-trainable params: 480
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, cooldown=1, verbose=1)# write the REducelronplateau code here
earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
callbacks_list = [checkpoint, LR, earlystop]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
model_d.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ../Project_data/train ; batch size = 10
# Epoch 1/30
# 65/67 [============================>.] - ETA: 3s - loss: 1.5290 - categorical_accuracy: 0.3446Batch:  67 Index: 10
# 67/67 [==============================] - ETA: 0s - loss: 1.5300 - categorical_accuracy: 0.3424Source path =  ../Project_data/val ; batch size = 10
#
# Epoch 00001: saving model to model_init_2022-05-1614_05_12.316824/model-00001-1.53000-0.34238-2.06204-0.16000.h5
# 67/67 [==============================] - 156s 2s/step - loss: 1.5300 - categorical_accuracy: 0.3424 - val_loss: 2.0620 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/30
# 67/67 [==============================] - ETA: 0s - loss: 1.5143 - categorical_accuracy: 0.3085
# Epoch 00002: saving model to model_init_2022-05-1614_05_12.316824/model-00002-1.51425-0.30846-1.99999-0.15000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 1.5143 - categorical_accuracy: 0.3085 - val_loss: 2.0000 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 3/30
# 67/67 [==============================] - ETA: 0s - loss: 1.6756 - categorical_accuracy: 0.2736
# Epoch 00003: saving model to model_init_2022-05-1614_05_12.316824/model-00003-1.67564-0.27363-2.44553-0.19000.h5
# 67/67 [==============================] - 70s 1s/step - loss: 1.6756 - categorical_accuracy: 0.2736 - val_loss: 2.4455 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 4/30
# 67/67 [==============================] - ETA: 0s - loss: 1.6714 - categorical_accuracy: 0.2139
# Epoch 00004: saving model to model_init_2022-05-1614_05_12.316824/model-00004-1.67137-0.21393-1.84795-0.21000.h5
# 67/67 [==============================] - 65s 983ms/step - loss: 1.6714 - categorical_accuracy: 0.2139 - val_loss: 1.8480 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 5/30
# 67/67 [==============================] - ETA: 0s - loss: 1.5156 - categorical_accuracy: 0.3234
# Epoch 00005: saving model to model_init_2022-05-1614_05_12.316824/model-00005-1.51565-0.32338-1.89404-0.19000.h5
# 67/67 [==============================] - 71s 1s/step - loss: 1.5156 - categorical_accuracy: 0.3234 - val_loss: 1.8940 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 6/30
# 67/67 [==============================] - ETA: 0s - loss: 1.5757 - categorical_accuracy: 0.3284
# Epoch 00006: saving model to model_init_2022-05-1614_05_12.316824/model-00006-1.57571-0.32836-1.98873-0.23000.h5
# 67/67 [==============================] - 71s 1s/step - loss: 1.5757 - categorical_accuracy: 0.3284 - val_loss: 1.9887 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 7/30
# 67/67 [==============================] - ETA: 0s - loss: 1.4043 - categorical_accuracy: 0.3881
# Epoch 00007: saving model to model_init_2022-05-1614_05_12.316824/model-00007-1.40432-0.38806-1.91013-0.17000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 1.4043 - categorical_accuracy: 0.3881 - val_loss: 1.9101 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 8/30
# 67/67 [==============================] - ETA: 0s - loss: 1.4780 - categorical_accuracy: 0.3483
# Epoch 00008: saving model to model_init_2022-05-1614_05_12.316824/model-00008-1.47804-0.34826-2.06765-0.19000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 67/67 [==============================] - 74s 1s/step - loss: 1.4780 - categorical_accuracy: 0.3483 - val_loss: 2.0677 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch
30
# 67/67 [==============================] - ETA: 0s - loss: 1.1662 - categorical_accuracy: 0.5423
# Epoch 00029: saving model to model_init_2022-05-1614_05_12.316824/model-00029-1.16621-0.54229-0.98665-0.66000.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 67/67 [==============================] - 69s 1s/step - loss: 1.1662 - categorical_accuracy: 0.5423 - val_loss: 0.9867 - val_categorical_accuracy: 0.6600 - lr: 4.0000e-05
# Epoch 30/30
# 67/67 [==============================] - ETA: 0s - loss: 1.1396 - categorical_accuracy: 0.5672
# Epoch 00030: saving model to model_init_2022-05-1614_05_12.316824/model-00030-1.13957-0.56716-0.98822-0.68000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 1.1396 - categorical_accuracy: 0.5672 - val_loss: 0.9882 - val_categorical_accuracy: 0.6800 - lr: 8.0000e-06

# %% [markdown]
# from the above model we can infer that the accuracy of training and validation are 56% and 68.0% respectively.<br>

# %% [markdown]
# #### Exp-6 : Let us add more dense nuerons and gru cells and examine the results

# %%
input_shape=(x,y,z,channels)
model_d1= Sequential()

model_d1.add(TimeDistributed(Conv2D(16, kernel_size=(3, 3),  padding='same'),input_shape=input_shape))
model_d1.add(TimeDistributed(Activation('relu')))
model_d1.add(TimeDistributed(BatchNormalization()))


model_d1.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d1.add(TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding='same')))
model_d1.add(TimeDistributed(Activation('relu')))
model_d1.add(TimeDistributed(BatchNormalization()))


model_d1.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d1.add(TimeDistributed(Conv2D(64, kernel_size=(3, 3),  padding='same')))
model_d1.add(TimeDistributed(Activation('relu')))
model_d1.add(TimeDistributed(BatchNormalization()))


model_d1.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d1.add(TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding='same')))
model_d1.add(TimeDistributed(Activation('relu')))
model_d1.add(TimeDistributed(BatchNormalization()))


model_d1.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d1.add(TimeDistributed(Flatten()))

model_d1.add(GRU(128))
model_d1.add(Dropout(0.25))

model_d1.add(Dense(128,activation='relu'))
model_d1.add(Dropout(0.25))

model_d1.add(Dense(classes, activation='softmax'))

# %%
optimiser=tf.keras.optimizers.Adam()
model_d1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_d1.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_17 (TimeDi  (None, 30, 100, 100, 16)  448
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 30, 100, 100, 16)  0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 30, 100, 100, 16)  64
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 30, 50, 50, 16)   0
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 30, 50, 50, 32)   4640
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 30, 50, 50, 32)   0
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 30, 50, 50, 32)   128
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 30, 25, 25, 32)   0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 30, 25, 25, 64)   18496
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 30, 25, 25, 64)   0
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 30, 25, 25, 64)   256
#  stributed)
#
#  time_distributed_28 (TimeDi  (None, 30, 12, 12, 64)   0
#  stributed)
#
#  time_distributed_29 (TimeDi  (None, 30, 12, 12, 128)  73856
#  stributed)
#
#  time_distributed_30 (TimeDi  (None, 30, 12, 12, 128)  0
#  stributed)
#
#  time_distributed_31 (TimeDi  (None, 30, 12, 12, 128)  512
#  stributed)
#
#  time_distributed_32 (TimeDi  (None, 30, 6, 6, 128)    0
#  stributed)
#
#  time_distributed_33 (TimeDi  (None, 30, 4608)         0
#  stributed)
#
#  gru_1 (GRU)                 (None, 128)               1819392
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None,
30
# 67/67 [==============================] - ETA: 0s - loss: 0.7722 - categorical_accuracy: 0.7065
# Epoch 00029: saving model to model_init_2022-05-1614_05_12.316824/model-00029-0.77223-0.70647-0.90947-0.62000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 0.7722 - categorical_accuracy: 0.7065 - val_loss: 0.9095 - val_categorical_accuracy: 0.6200 - lr: 2.0000e-04
# Epoch 30/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7664 - categorical_accuracy: 0.6866
# Epoch 00030: saving model to model_init_2022-05-1614_05_12.316824/model-00030-0.76642-0.68657-0.87143-0.63000.h5
# 67/67 [==============================] - 70s 1s/step - loss: 0.7664 - categorical_accuracy: 0.6866 - val_loss: 0.8714 - val_categorical_accuracy: 0.6300 - lr: 2.0000e-04

# %% [markdown]
# #### Improvement in accuracy is observed

# %% [markdown]
# #### Exp-7: add layers in GRU

# %%
input_shape=(x,y,z,channels)
model_d2= Sequential()

model_d2.add(TimeDistributed(Conv2D(16, kernel_size=(3, 3),  padding='same'),input_shape=input_shape))
model_d2.add(TimeDistributed(Activation('relu')))
model_d2.add(TimeDistributed(BatchNormalization()))


model_d2.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d2.add(TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding='same')))
model_d2.add(TimeDistributed(Activation('relu')))
model_d2.add(TimeDistributed(BatchNormalization()))


model_d2.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d2.add(TimeDistributed(Conv2D(64, kernel_size=(3, 3),  padding='same')))
model_d2.add(TimeDistributed(Activation('relu')))
model_d2.add(TimeDistributed(BatchNormalization()))


model_d2.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d2.add(TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding='same')))
model_d2.add(TimeDistributed(Activation('relu')))
model_d2.add(TimeDistributed(BatchNormalization()))


model_d2.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d2.add(TimeDistributed(Flatten()))

model_d2.add(GRU(128,return_sequences=True))
model_d2.add(Dropout(0.25))

model_d2.add(GRU(128))
model_d2.add(Dropout(0.25))


model_d2.add(Dense(128,activation='relu'))
model_d2.add(Dropout(0.25))

model_d2.add(Dense(classes, activation='softmax'))

# %%
optimiser=tf.keras.optimizers.Adam()
model_d2.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_d2.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_34 (TimeDi  (None, 30, 100, 100, 16)  448
#  stributed)
#
#  time_distributed_35 (TimeDi  (None, 30, 100, 100, 16)  0
#  stributed)
#
#  time_distributed_36 (TimeDi  (None, 30, 100, 100, 16)  64
#  stributed)
#
#  time_distributed_37 (TimeDi  (None, 30, 50, 50, 16)   0
#  stributed)
#
#  time_distributed_38 (TimeDi  (None, 30, 50, 50, 32)   4640
#  stributed)
#
#  time_distributed_39 (TimeDi  (None, 30, 50, 50, 32)   0
#  stributed)
#
#  time_distributed_40 (TimeDi  (None, 30, 50, 50, 32)   128
#  stributed)
#
#  time_distributed_41 (TimeDi  (None, 30, 25, 25, 32)   0
#  stributed)
#
#  time_distributed_42 (TimeDi  (None, 30, 25, 25, 64)   18496
#  stributed)
#
#  time_distributed_43 (TimeDi  (None, 30, 25, 25, 64)   0
#  stributed)
#
#  time_distributed_44 (TimeDi  (None, 30, 25, 25, 64)   256
#  stributed)
#
#  time_distributed_45 (TimeDi  (None, 30, 12, 12, 64)   0
#  stributed)
#
#  time_distributed_46 (TimeDi  (None, 30, 12, 12, 128)  73856
#  stributed)
#
#  time_distributed_47 (TimeDi  (None, 30, 12, 12, 128)  0
#  stributed)
#
#  time_distributed_48 (TimeDi  (None, 30, 12, 12, 128)  512
#  stributed)
#
#  time_distributed_49 (TimeDi  (None, 30, 6, 6, 128)    0
#  stributed)
#
#  time_distributed_50 (TimeDi  (None, 30, 4608)         0
#  stributed)
#
#  gru_2 (GRU)                 (None, 30, 128)           1819392
#
#  dropout_11 (Dropout)        (None, 30, 128)           0
#
#  gru_3 (GRU)                 (None, 128)               99072
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 128)               16512
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 2,034,021
# Trainable params: 2,033,541
# Non-trainable params: 480
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_d2.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ../Project_data/train ; batch size = 10
# Epoch 1/30
# 65/67 [============================>.] - ETA: 4s - loss: 1.4675 - categorical_accuracy: 0.3492Batch:  67 Index: 10
# 67/67 [==============================] - ETA: 0s - loss: 1.4657 - categorical_accuracy: 0.3514Source path =  ../Project_data/val ; batch size = 10
#
# Epoch 00001: saving model to model_init_2022-05-1614_05_12.316824/model-00001-1.46574-0.35143-1.72647-0.22000.h5
# 67/67 [==============================] - 174s 3s/step - loss: 1.4657 - categorical_accuracy: 0.3514 - val_loss: 1.7265 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 2/30
# 67/67 [==============================] - ETA: 0s - loss: 1.5072 - categorical_accuracy: 0.4030
# Epoch 00002: saving model to model_init_2022-05-1614_05_12.316824/model-00002-1.50717-0.40299-1.72544-0.22000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 1.5072 - categorical_accuracy: 0.4030 - val_loss: 1.7254 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 3/30
# 67/67 [==============================] - ETA: 0s - loss: 1.3443 - categorical_accuracy: 0.3881
# Epoch 00003: saving model to model_init_2022-05-1614_05_12.316824/model-00003-1.34434-0.38806-2.11178-0.23000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 1.3443 - categorical_accuracy: 0.3881 - val_loss: 2.1118 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 4/30
# 67/67 [==============================] - ETA: 0s - loss: 1.3556 - categorical_accuracy: 0.4378
# Epoch 00004: saving model to model_init_2022-05-1614_05_12.316824/model-00004-1.35559-0.43781-2.65030-0.21000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 1.3556 - categorical_accuracy: 0.4378 - val_loss: 2.6503 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 5/30
# 67/67 [==============================] - ETA: 0s - loss: 1.1877 - categorical_accuracy: 0.5274
# Epoch 00005: saving model to model_init_2022-05-1614_05_12.316824/model-00005-1.18771-0.52736-2.59007-0.23000.h5
# 67/67 [==============================] - 65s 981ms/step - loss: 1.1877 - categorical_accuracy: 0.5274 - val_loss: 2.5901 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 6/30
# 67/67 [==============================] - ETA: 0s - loss: 1.2338 - categorical_accuracy: 0.5224
# Epoch 00006: saving model to model_init_2022-05-1614_05_12.316824/model-00006-1.23383-0.52239-2.05845-0.33000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 67/67 [==============================] - 73s 1s/step - loss: 1.2338 - categorical_accuracy: 0.5224 - val_loss: 2.0584 - val_categorical_accuracy: 0.3300 - lr: 0.0010
# Epoch 7/30
# 67/67 [==============================] - ETA: 0s - loss: 1.1973 - categorical_accuracy: 0.5622
# Epoch 00007: saving model to model_init_2022-05-1614_05_12.316824/model-00007-1.19727-0.56219-2.79021-0.24000.h5
# 67/67 [==============================] - 66s 1s/step - loss: 1.1973 - categorical_accuracy: 0.5622 - val_loss: 2.7902 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 8/30
# 67/67 [==============================] - ETA: 0s - loss: 1.0786 - categorical_accuracy: 0.6169
# Epoch 00008: saving model to model_init_2022-05-1614_05_12.316824/model-00008-1.07856-0.61692-2.74296-0.29000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 1.0786 - categorical_accuracy: 0.6169 - val_loss: 2.7430 - val_categorical_accuracy: 0.2900 - lr: 2.0000e-04
# Epoch 9/30
# 67/67 [==============================] - ETA: 0s - loss: 0.9055 - categorical_accuracy: 0.6965
# Epoch 00009: saving model to model_init_2022-05-1614_05_12.316824/model-00009-0.90552-0.69652-3.07654-0.23000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 0.9055 - categorical_accuracy: 0.6965 - val_loss: 3.0765 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 10/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8600 - categorical_accuracy: 0.6816
# Epoch 00010: saving model to model_init_2022-05-1614_05_12.316824/model-00010-0.86005-0.68159-2.59061-0.30000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 67/67 [==============================] - 69s 1s/step - loss: 0.8600 - categorical_accuracy: 0.6816 - val_loss: 2.5906 - val_categorical_accuracy: 0.3000 - lr: 2.0000e-04
# Epoch 11/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8063 - categorical_accuracy: 0.7164
# Epoch 00011: saving model to model_init_2022-05-1614_05_12.316824/model-00011-0.80632-0.71642-1.79550-0.39000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 0.8063 - categorical_accuracy: 0.7164 - val_loss: 1.7955 - val_categorical_accuracy: 0.3900 - lr: 4.0000e-05
# Epoch 12/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8141 - categorical_accuracy: 0.7015
# Epoch 00012: saving model to model_init_2022-05-1614_05_12.316824/model-00012-0.81412-0.70149-1.21400-0.61000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 0.8141 - categorical_accuracy: 0.7015 - val_loss: 1.2140 - val_categorical_accuracy: 0.6100 - lr: 4.0000e-05
# Epoch 13/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5842 - categorical_accuracy: 0.8259
# Epoch 00013: saving model to model_init_2022-05-1614_05_12.316824/model-00013-0.58420-0.82587-0.90489-0.67000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 0.5842 - categorical_accuracy: 0.8259 - val_loss: 0.9049 - val_categorical_accuracy: 0.6700 - lr: 4.0000e-05
# Epoch 14/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6428 - categorical_accuracy: 0.7761
# Epoch 00014: saving model to model_init_2022-05-1614_05_12.316824/model-00014-0.64276-0.77612-0.90209-0.66000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.6428 - categorical_accuracy: 0.7761 - val_loss: 0.9021 - val_categorical_accuracy: 0.6600 - lr: 4.0000e-05
# Epoch 15/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6865 - categorical_accuracy: 0.7711
# Epoch 00015: saving model to model_init_2022-05-1614_05_12.316824/model-00015-0.68655-0.77114-0.88248-0.66000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 0.6865 - categorical_accuracy: 0.7711 - val_loss: 0.8825 - val_categorical_accuracy: 0.6600 - lr: 4.0000e-05
# Epoch 16/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7000 - categorical_accuracy: 0.7363
# Epoch 00016: saving model to model_init_2022-05-1614_05_12.316824/model-00016-0.70002-0.73632-0.83500-0.69000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 0.7000 - categorical_accuracy: 0.7363 - val_loss: 0.8350 - val_categorical_accuracy: 0.6900 - lr: 4.0000e-05
# Epoch 17/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7294 - categorical_accuracy: 0.7264
# Epoch 00017: saving model to model_init_2022-05-1614_05_12.316824/model-00017-0.72943-0.72637-0.75278-0.68000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.7294 - categorical_accuracy: 0.7264 - val_loss: 0.7528 - val_categorical_accuracy: 0.6800 - lr: 4.0000e-05
# Epoch 18/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5770 - categorical_accuracy: 0.7811
# Epoch 00018: saving model to model_init_2022-05-1614_05_12.316824/model-00018-0.57700-0.78109-0.74444-0.70000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 0.5770 - categorical_accuracy: 0.7811 - val_loss: 0.7444 - val_categorical_accuracy: 0.7000 - lr: 4.0000e-05
# Epoch 19/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6970 - categorical_accuracy: 0.7562
# Epoch 00019: saving model to model_init_2022-05-1614_05_12.316824/model-00019-0.69700-0.75622-0.77227-0.70000.h5
# 67/67 [==============================] - 64s 975ms/step - loss: 0.6970 - categorical_accuracy: 0.7562 - val_loss: 0.7723 - val_categorical_accuracy: 0.7000 - lr: 4.0000e-05
# Epoch 20/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6142 - categorical_accuracy: 0.7960
# Epoch 00020: saving model to model_init_2022-05-1614_05_12.316824/model-00020-0.61421-0.79602-0.80219-0.67000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.6142 - categorical_accuracy: 0.7960 - val_loss: 0.8022 - val_categorical_accuracy: 0.6700 - lr: 4.0000e-05
# Epoch 21/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5740 - categorical_accuracy: 0.8159
# Epoch 00021: saving model to model_init_2022-05-1614_05_12.316824/model-00021-0.57398-0.81592-0.75140-0.67000.h5
# 67/67 [==============================] - 70s 1s/step - loss: 0.5740 - categorical_accuracy: 0.8159 - val_loss: 0.7514 - val_categorical_accuracy: 0.6700 - lr: 4.0000e-05
# Epoch 22/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5188 - categorical_accuracy: 0.8458
# Epoch 00022: saving model to model_init_2022-05-1614_05_12.316824/model-00022-0.51876-0.84577-0.76591-0.71000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 67/67 [==============================] - 72s 1s/step - loss: 0.5188 - categorical_accuracy: 0.8458 - val_loss: 0.7659 - val_categorical_accuracy: 0.7100 - lr: 4.0000e-05
# Epoch 23/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5689 - categorical_accuracy: 0.8109
# Epoch 00023: saving model to model_init_2022-05-1614_05_12.316824/model-00023-0.56890-0.81095-0.73636-0.71000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 0.5689 - categorical_accuracy: 0.8109 - val_loss: 0.7364 - val_categorical_accuracy: 0.7100 - lr: 8.0000e-06
# Epoch 24/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5454 - categorical_accuracy: 0.8060
# Epoch 00024: saving model to model_init_2022-05-1614_05_12.316824/model-00024-0.54541-0.80597-0.61355-0.79000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.5454 - categorical_accuracy: 0.8060 - val_loss: 0.6135 - val_categorical_accuracy: 0.7900 - lr: 8.0000e-06
# Epoch 25/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5617 - categorical_accuracy: 0.8209
# Epoch 00025: saving model to model_init_2022-05-1614_05_12.316824/model-00025-0.56172-0.82090-0.81521-0.68000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.5617 - categorical_accuracy: 0.8209 - val_loss: 0.8152 - val_categorical_accuracy: 0.6800 - lr: 8.0000e-06
# Epoch 26/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5948 - categorical_accuracy: 0.8109
# Epoch 00026: saving model to model_init_2022-05-1614_05_12.316824/model-00026-0.59481-0.81095-0.72987-0.75000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.5948 - categorical_accuracy: 0.8109 - val_loss: 0.7299 - val_categorical_accuracy: 0.7500 - lr: 8.0000e-06
# Epoch 27/30
# 67/67 [==============================] - ETA: 0s - loss: 0.4704 - categorical_accuracy: 0.8557
# Epoch 00027: saving model to model_init_2022-05-1614_05_12.316824/model-00027-0.47037-0.85572-0.80693-0.66000.h5
# 67/67 [==============================] - 75s 1s/step - loss: 0.4704 - categorical_accuracy: 0.8557 - val_loss: 0.8069 - val_categorical_accuracy: 0.6600 - lr: 8.0000e-06
# Epoch 28/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5829 - categorical_accuracy: 0.7761
# Epoch 00028: saving model to model_init_2022-05-1614_05_12.316824/model-00028-0.58288-0.77612-0.76100-0.72000.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 67/67 [==============================] - 79s 1s/step - loss: 0.5829 - categorical_accuracy: 0.7761 - val_loss: 0.7610 - val_categorical_accuracy: 0.7200 - lr: 8.0000e-06
# Epoch 29/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5447 - categorical_accuracy: 0.7960
# Epoch 00029: saving model to model_init_2022-05-1614_05_12.316824/model-00029-0.54466-0.79602-0.67535-0.76000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 0.5447 - categorical_accuracy: 0.7960 - val_loss: 0.6754 - val_categorical_accuracy: 0.7600 - lr: 1.6000e-06
# Epoch 30/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5231 - categorical_accuracy: 0.8060
# Epoch 00030: saving model to model_init_2022-05-1614_05_12.316824/model-00030-0.52311-0.80597-0.78526-0.69000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 0.5231 - categorical_accuracy: 0.8060 - val_loss: 0.7853 - val_categorical_accuracy: 0.6900 - lr: 1.6000e-06

# %% [markdown]
# Training acciracy is 80% and validation accuracy is 69%. Let try to improve it further as there is a slight possibility of overfitting.

# %% [markdown]
# #### Exp-8 :Add dropouts,and set the learning rate to 0.0001

# %%
input_shape=(x,y,z,channels)
model_d3= Sequential()

model_d3.add(TimeDistributed(Conv2D(16, kernel_size=(3, 3),  padding='same'),input_shape=input_shape))
model_d3.add(TimeDistributed(Activation('relu')))
model_d3.add(TimeDistributed(BatchNormalization()))


model_d3.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))


model_d3.add(TimeDistributed(Conv2D(32, kernel_size=(3, 3), padding='same')))
model_d3.add(TimeDistributed(Activation('relu')))
model_d3.add(TimeDistributed(BatchNormalization()))


model_d3.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))

model_d3.add(TimeDistributed(Conv2D(64, kernel_size=(3, 3),  padding='same')))
model_d3.add(TimeDistributed(Activation('relu')))
model_d3.add(TimeDistributed(BatchNormalization()))


model_d3.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))


model_d3.add(TimeDistributed(Conv2D(128, kernel_size=(3, 3), padding='same')))
model_d3.add(TimeDistributed(Activation('relu')))
model_d3.add(TimeDistributed(BatchNormalization()))


model_d3.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model_d3.add(Dropout(0.25))

model_d3.add(TimeDistributed(Flatten()))

model_d3.add(GRU(128,return_sequences=True))
model_d3.add(Dropout(0.25))

model_d3.add(GRU(128))
model_d3.add(Dropout(0.25))


model_d3.add(Dense(128,activation='relu'))
model_d3.add(Dropout(0.25))

model_d3.add(Dense(classes, activation='softmax'))

# %%
optimiser=tf.keras.optimizers.Adam(0.0001)
model_d3.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_d3.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_51 (TimeDi  (None, 30, 100, 100, 16)  448
#  stributed)
#
#  time_distributed_52 (TimeDi  (None, 30, 100, 100, 16)  0
#  stributed)
#
#  time_distributed_53 (TimeDi  (None, 30, 100, 100, 16)  64
#  stributed)
#
#  time_distributed_54 (TimeDi  (None, 30, 50, 50, 16)   0
#  stributed)
#
#  time_distributed_55 (TimeDi  (None, 30, 50, 50, 32)   4640
#  stributed)
#
#  time_distributed_56 (TimeDi  (None, 30, 50, 50, 32)   0
#  stributed)
#
#  time_distributed_57 (TimeDi  (None, 30, 50, 50, 32)   128
#  stributed)
#
#  time_distributed_58 (TimeDi  (None, 30, 25, 25, 32)   0
#  stributed)
#
#  time_distributed_59 (TimeDi  (None, 30, 25, 25, 64)   18496
#  stributed)
#
#  time_distributed_60 (TimeDi  (None, 30, 25, 25, 64)   0
#  stributed)
#
#  time_distributed_61 (TimeDi  (None, 30, 25, 25, 64)   256
#  stributed)
#
#  time_distributed_62 (TimeDi  (None, 30, 12, 12, 64)   0
#  stributed)
#
#  time_distributed_63 (TimeDi  (None, 30, 12, 12, 128)  73856
#  stributed)
#
#  time_distributed_64 (TimeDi  (None, 30, 12, 12, 128)  0
#  stributed)
#
#  time_distributed_65 (TimeDi  (None, 30, 12, 12, 128)  512
#  stributed)
#
#  time_distributed_66 (TimeDi  (None, 30, 6, 6, 128)    0
#  stributed)
#
#  dropout_14 (Dropout)        (None, 30, 6, 6, 128)     0
#
#  time_distributed_67 (TimeDi  (None, 30, 4608)         0
#  stributed)
#
#  gru_4 (GRU)                 (None, 30, 128)           1819392
#
#  dropout_15 (Dropout)        (None, 30, 128)           0
#
#  gru_5 (GRU)                 (None, 128)               99072
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 128)               16512
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 2,034,021
# Trainable params: 2,033,541
# Non-trainable params: 480
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_d3.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ../Project_data/train ; batch size = 10
# Epoch 1/30
# 2022-05-16 16:58:49.597630: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 65/67 [============================>.] - ETA: 3s - loss: 1.5271 - categorical_accuracy: 0.3369Batch:  67 Index: 10
# 67/67 [==============================] - ETA: 0s - loss: 1.5240 - categorical_accuracy: 0.3363Source path =  ../Project_data/val ; batch size = 10
#
# Epoch 00001: saving model to model_init_2022-05-1616_57_18.589445/model-00001-1.52399-0.33635-1.71988-0.16000.h5
# 67/67 [==============================] - 160s 2s/step - loss: 1.5240 - categorical_accuracy: 0.3363 - val_loss: 1.7199 - val_categorical_accuracy: 0.1600 - lr: 1.0000e-04
# Epoch 2/30
# 67/67 [==============================] - ETA: 0s - loss: 1.3287 - categorical_accuracy: 0.4229
# Epoch 00002: saving model to model_init_2022-05-1616_57_18.589445/model-00002-1.32873-0.42289-1.92667-0.15000.h5
# 67/67 [==============================] - 62s 930ms/step - loss: 1.3287 - categorical_accuracy: 0.4229 - val_loss: 1.9267 - val_categorical_accuracy: 0.1500 - lr: 1.0000e-04
# Epoch 3/30
# 67/67 [==============================] - ETA: 0s - loss: 1.2744 - categorical_accuracy: 0.4726
# Epoch 00003: saving model to model_init_2022-05-1616_57_18.589445/model-00003-1.27440-0.47264-1.90980-0.18000.h5
# 67/67 [==============================] - 64s 969ms/step - loss: 1.2744 - categorical_accuracy: 0.4726 - val_loss: 1.9098 - val_categorical_accuracy: 0.1800 - lr: 1.0000e-04
# Epoch 4/30
# 67/67 [==============================] - ETA: 0s - loss: 1.1541 - categorical_accuracy: 0.5522
# Epoch 00004: saving model to model_init_2022-05-1616_57_18.589445/model-00004-1.15413-0.55224-2.09615-0.14000.h5
# 67/67 [==============================] - 62s 937ms/step - loss: 1.1541 - categorical_accuracy: 0.5522 - val_loss: 2.0961 - val_categorical_accuracy: 0.1400 - lr: 1.0000e-04
# Epoch 5/30
# 67/67 [==============================] - ETA: 0s - loss: 1.0362 - categorical_accuracy: 0.6020
# Epoch 00005: saving model to model_init_2022-05-1616_57_18.589445/model-00005-1.03620-0.60199-1.97916-0.17000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
30
# 67/67 [==============================] - ETA: 0s - loss: 0.7131 - categorical_accuracy: 0.8060
# Epoch 00013: saving model to model_init_2022-05-1616_57_18.589445/model-00013-0.71312-0.80597-0.89358-0.61000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 0.7131 - categorical_accuracy: 0.8060 - val_loss: 0.8936 - val_categorical_accuracy: 0.6100 - lr: 4.0000e-06
# Epoch 14/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7534 - categorical_accuracy: 0.7264
# Epoch 00014: saving model to model_init_2022-05-1616_57_18.589445/model-00014-0.75342-0.72637-0.76463-0.74000.h5
# 67/67 [==============================] - 66s 994ms/step - loss: 0.7534 - categorical_accuracy: 0.7264 - val_loss: 0.7646 - val_categorical_accuracy: 0.7400 - lr: 4.0000e-06
# Epoch 15/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7486 - categorical_accuracy: 0.7413
# Epoch 00015: saving model to model_init_2022-05-1616_57_18.589445/model-00015-0.74859-0.74129-0.84449-0.72000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 0.7486 - categorical_accuracy: 0.7413 - val_loss: 0.8445 - val_categorical_accuracy: 0.7200 - lr: 4.0000e-06
# Epoch 16/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7050 - categorical_accuracy: 0.7512
# Epoch 00016: saving model to model_init_2022-05-1616_57_18.589445/model-00016-0.70498-0.75124-0.75118-0.75000.h5
# 67/67 [==============================] - 70s 1s/step - loss: 0.7050 - categorical_accuracy: 0.7512 - val_loss: 0.7512 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-06
# Epoch 17/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6551 - categorical_accuracy: 0.7761
# Epoch 00017: saving model to model_init_2022-05-1616_57_18.589445/model-00017-0.65511-0.77612-0.73507-0.75000.h5
# 67/67 [==============================] - 67s 1s/step - loss: 0.6551 - categorical_accuracy: 0.7761 - val_loss: 0.7351 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-06
# Epoch 18/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6464 - categorical_accuracy: 0.8060
# Epoch 00018: saving model to model_init_2022-05-1616_57_18.589445/model-00018-0.64641-0.80597-0.79522-0.72000.h5
# 67/67 [==============================] - 64s 965ms/step - loss: 0.6464 - categorical_accuracy: 0.8060 - val_loss: 0.7952 - val_categorical_accuracy: 0.7200 - lr: 4.0000e-06
# Epoch 19/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6900 - categorical_accuracy: 0.7413
# Epoch 00019: saving model to model_init_2022-05-1616_57_18.589445/model-00019-0.69005-0.74129-0.83418-0.68000.h5
# 67/67 [==============================] - 70s 1s/step - loss: 0.6900 - categorical_accuracy: 0.7413 - val_loss: 0.8342 - val_categorical_accuracy: 0.6800 - lr: 4.0000e-06
# Epoch 20/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7043 - categorical_accuracy: 0.7761
# Epoch 00020: saving model to model_init_2022-05-1616_57_18.589445/model-00020-0.70425-0.77612-0.83240-0.71000.h5
# 67/67 [==============================] - 76s 1s/step - loss: 0.7043 - categorical_accuracy: 0.7761 - val_loss: 0.8324 - val_categorical_accuracy: 0.7100 - lr: 4.0000e-06
# Epoch 21/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7143 - categorical_accuracy: 0.7463
# Epoch 00021: saving model to model_init_2022-05-1616_57_18.589445/model-00021-0.71429-0.74627-0.79085-0.72000.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 67/67 [==============================] - 66s 996ms/step - loss: 0.7143 - categorical_accuracy: 0.7463 - val_loss: 0.7909 - val_categorical_accuracy: 0.7200 - lr: 4.0000e-06
# Epoch 22/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7178 - categorical_accuracy: 0.7711
# Epoch 00022: saving model to model_init_2022-05-1616_57_18.589445/model-00022-0.71779-0.77114-0.74016-0.75000.h5
# 67/67 [==============================] - 66s 1s/step - loss: 0.7178 - categorical_accuracy: 0.7711 - val_loss: 0.7402 - val_categorical_accuracy: 0.7500 - lr: 8.0000e-07
# Epoch 23/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6787 - categorical_accuracy: 0.7960
# Epoch 00023: saving model to model_init_2022-05-1616_57_18.589445/model-00023-0.67866-0.79602-0.82866-0.72000.h5
# 67/67 [==============================] - 66s 1s/step - loss: 0.6787 - categorical_accuracy: 0.7960 - val_loss: 0.8287 - val_categorical_accuracy: 0.7200 - lr: 8.0000e-07
# Epoch 24/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6920 - categorical_accuracy: 0.7562
# Epoch 00024: saving model to model_init_2022-05-1616_57_18.589445/model-00024-0.69197-0.75622-0.78497-0.73000.h5
# 67/67 [==============================] - 65s 985ms/step - loss: 0.6920 - categorical_accuracy: 0.7562 - val_loss: 0.7850 - val_categorical_accuracy: 0.7300 - lr: 8.0000e-07
# Epoch 25/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6402 - categorical_accuracy: 0.8408
# Epoch 00025: saving model to model_init_2022-05-1616_57_18.589445/model-00025-0.64023-0.84080-0.77901-0.74000.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 67/67 [==============================] - 67s 1s/step - loss: 0.6402 - categorical_accuracy: 0.8408 - val_loss: 0.7790 - val_categorical_accuracy: 0.7400 - lr: 8.0000e-07
# Epoch 26/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7085 - categorical_accuracy: 0.8010
# Epoch 00026: saving model to model_init_2022-05-1616_57_18.589445/model-00026-0.70852-0.80100-0.71054-0.79000.h5
# 67/67 [==============================] - 65s 989ms/step - loss: 0.7085 - categorical_accuracy: 0.8010 - val_loss: 0.7105 - val_categorical_accuracy: 0.7900 - lr: 1.6000e-07
# Epoch 27/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6572 - categorical_accuracy: 0.7910
# Epoch 00027: saving model to model_init_2022-05-1616_57_18.589445/model-00027-0.65724-0.79104-0.84401-0.72000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 0.6572 - categorical_accuracy: 0.7910 - val_loss: 0.8440 - val_categorical_accuracy: 0.7200 - lr: 1.6000e-07
# Epoch 28/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6365 - categorical_accuracy: 0.8209
# Epoch 00028: saving model to model_init_2022-05-1616_57_18.589445/model-00028-0.63652-0.82090-0.74838-0.73000.h5
# 67/67 [==============================] - 71s 1s/step - loss: 0.6365 - categorical_accuracy: 0.8209 - val_loss: 0.7484 - val_categorical_accuracy: 0.7300 - lr: 1.6000e-07
# Epoch 29/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6617 - categorical_accuracy: 0.7811
# Epoch 00029: saving model to model_init_2022-05-1616_57_18.589445/model-00029-0.66172-0.78109-0.82770-0.70000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 0.6617 - categorical_accuracy: 0.7811 - val_loss: 0.8277 - val_categorical_accuracy: 0.7000 - lr: 1.6000e-07
# Epoch 30/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7137 - categorical_accuracy: 0.8209
# Epoch 00030: saving model to model_init_2022-05-1616_57_18.589445/model-00030-0.71367-0.82090-0.73877-0.76000.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 67/67 [==============================] - 69s 1s/step - loss: 0.7137 - categorical_accuracy: 0.8209 - val_loss: 0.7388 - val_categorical_accuracy: 0.7600 - lr: 1.6000e-07

# %% [markdown]
#  training accuracy is 82% and the validation accuracy is 76.0%.But the loss is too high and it didnt decreased.

# %% [markdown]
# ## Thus final model is Exp-4 with Training Accuracy: 0.92, Validation accuracy:-0.85 with least number of parameters.
